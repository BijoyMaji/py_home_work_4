# %%
Q1. First part theoory question,f(x)=2-∑ {4}{n^2\pi^2

# %%
import numpy as np
n=int(input('enter the number \n'))
xsum = 0.0
for i in range(0,n+1):
    xsum +=1./(2*i+1)**2
print ("calculated value,actual value")
ac=(np.pi)**2/8.
print (xsum,ac)
# Out:
# enter the number
# 10
# calculated value,actual value
# 1.2109888848175334 1.2337005501361697

# %%
Q2

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy.integrate import odeint
def model(u,t):
    x=u[0]
    y=u[1]
    dxdt=y
    dydt=-2*y-x
    return np.array([dxdt,dydt])
u0=[1,0] #initial condition
t=np.linspace(0,20,100)
sol=odeint(model,u0,t)
x=sol[:,0]
y=sol[:,1]
plt.plot(t,x)
plt.show()

# %%
#2(b)
import math
x=int(input('angle in degree: \n'))
tol=float (input("Tolerance:"))
x=x*math.pi/180
xsum,term=0,x
n=1
while abs(term)>tol:
    xsum+=term
    term=term*(-x**2/(2*n*(2*n+1)))
    n+=1
print ('calculated value,actual value')
print (xsum,math.sin(x))
# Out:
# angle in degree:
# 30
# Tolerance:0.001
# calculated value,actual value
# 0.49967417939436376 0.49999999999999994

# %%
import numpy as np

import matplotlib.pyplot as plt
from scipy import signal
t=np.linspace(-4,4,500)
v=(4*signal.square(2*np.pi*0.25*t)+4)/2
L=2 # half period
def f(t):return (4*4./np.pi*sum([1.0/n*np.sin(n*np.pi*t/L) for n in
range(1,10,2)])+4)/2
plt.plot(t,v,t,f(t))
plt.show()

# %%
from scipy.integrate import quad
from scipy.special import legendre
p2=legendre(2)
p3=legendre(3)
I1=quad(p2*p3,-1,1)
I2=quad(p2*p2,-1,1)
print('for pn different, value of integral=',I1)
print('for pn same, value of integral=',I2)
# Out:
# for pn different, value of integral= (0.0, 2.9638938867155025e-15)
# for pn same, value of integral= (0.4000000000000001, 4.440892098500627e-15)

# %%
import numpy as np

import matplotlib.pyplot as plt
from scipy.special import legendre
N=1000
xvalue=np.linspace(-1,1,N)
for i in range(1,5):
    pn=legendre(i)
    plt.plot(xvalue,pn(xvalue),label="n="+str(i))
    plt.legend(loc='upper center')
plt.title('Legendre Polynomials')
plt.show()

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy.integrate import odeint
def model(u,t):
    x=u[0]
    y=u[1]
    dxdt=y
    dydt=4.5-x/0.9 -0.5*y
    return np.array([dxdt,dydt])
u0=[1,0] #initial condition
t=np.linspace(0,10,100)
sol=odeint(model,u0,t)
x=sol[:,0]
y=sol[:,1]
plt.plot(t,y)
plt.show()

# %%
#5(b)

import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as s
y=s.triang(51)
L=50.0
def f(x):
    return 8.0/(np.pi**2)*sum([((-1.0)**((n-1)/2.))/n**2*np.sin(n*np.pi*x/L) for n in range(1,20,2)])
x=np.linspace(0,50,100)
plt.plot(x,f(x)),plt.plot(y)
plt.show()

# %%
#6(b)

import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,4,5])
y=np.array([.5,3.8,7.9,16.5,27.3])
f=np.polyfit(x,y,2)
p=np.poly1d(f)
plt.plot(x,p(x),label='fit')
plt.scatter(x,y,label='data')
plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt
from scipy.fftpack import fft
n=100
x=np.linspace(0.0,2,n)
freq=np.linspace(0.0,2,n//2)
y=np.exp(-x**2)
yf=fft(y)
ya=np.abs(yf)
plt.plot(freq,ya[:n//2])
plt.show()

# %%
#9(b)
import cmath
z=-5+12j
print (cmath.sqrt(z))
# Out:
# (2+3j)
